# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## **Input of Countries (*3 Countries*)**

# %%
csv_covid_19 = pd.read_csv('./covid_19_data.csv')
csv_covid_19.head()
country1 = input();
country2 = input();
country3 = input();
# Out:
# Latvia
# Lithuania
# Estonia

# %%
csv_covid_19.describe()
# Out:
#                 SNo      Confirmed        Deaths      Recovered
# count  19286.000000   19286.000000  19286.000000   19286.000000
# mean    9643.500000    3341.315047    203.872187     860.104376
# std     5567.532981   16284.544351   1488.983174    6194.791581
# min        1.000000       0.000000      0.000000       0.000000
# 25%     4822.250000      10.000000      0.000000       0.000000
# 50%     9643.500000     111.000000      1.000000       2.000000
# 75%    14464.750000     743.000000      9.000000      77.000000
# max    19286.000000  291996.000000  26977.000000  120832.000000

# %% [markdown]
# ## **Data treatment on Dates**

# %%
for index, row in csv_covid_19.iterrows():
  monthDay = row['ObservationDate'][0:5]
  csv_covid_19.loc[index, 'MonthDay'] = monthDay

csv_covid_19.head()
# Out:
#    SNo ObservationDate Province/State  ... Deaths Recovered  MonthDay
# 0    1      01/22/2020          Anhui  ...    0.0       0.0     01/22
# 1    2      01/22/2020        Beijing  ...    0.0       0.0     01/22
# 2    3      01/22/2020      Chongqing  ...    0.0       0.0     01/22
# 3    4      01/22/2020         Fujian  ...    0.0       0.0     01/22
# 4    5      01/22/2020          Gansu  ...    0.0       0.0     01/22
#
# [5 rows x 9 columns]

# %% [markdown]
# ## **Frame structure for each Country selected**

# %%
covid_19_country1 = csv_covid_19.where(csv_covid_19["Country/Region"]==country1).sort_values(by='ObservationDate')
covid_19_country1.head()
# Out:
#          SNo ObservationDate Province/State  ... Deaths Recovered  MonthDay
# 3052  3053.0      03/02/2020            NaN  ...    0.0       0.0     03/02
# 3201  3202.0      03/03/2020            NaN  ...    0.0       0.0     03/03
# 3362  3363.0      03/04/2020            NaN  ...    0.0       0.0     03/04
# 3531  3532.0      03/05/2020            NaN  ...    0.0       0.0     03/05
# 3719  3720.0      03/06/2020            NaN  ...    0.0       0.0     03/06
#
# [5 rows x 9 columns]

# %%
covid_19_country2 = csv_covid_19.where(csv_covid_19["Country/Region"]==country2).sort_values(by='ObservationDate')
covid_19_country2.head()
# Out:
#          SNo ObservationDate Province/State  ... Deaths Recovered  MonthDay
# 2677  2678.0      02/28/2020            NaN  ...    0.0       0.0     02/28
# 2794  2795.0      02/29/2020            NaN  ...    0.0       0.0     02/29
# 2920  2921.0      03/01/2020            NaN  ...    0.0       0.0     03/01
# 3053  3054.0      03/02/2020            NaN  ...    0.0       0.0     03/02
# 3202  3203.0      03/03/2020            NaN  ...    0.0       0.0     03/03
#
# [5 rows x 9 columns]

# %%
covid_19_country3 = csv_covid_19.where(csv_covid_19["Country/Region"]==country3).sort_values(by='ObservationDate')
covid_19_country3.head()
# Out:
#          SNo ObservationDate Province/State  ... Deaths Recovered  MonthDay
# 2564  2565.0      02/27/2020            NaN  ...    0.0       0.0     02/27
# 2674  2675.0      02/28/2020            NaN  ...    0.0       0.0     02/28
# 2790  2791.0      02/29/2020            NaN  ...    0.0       0.0     02/29
# 2918  2919.0      03/01/2020            NaN  ...    0.0       0.0     03/01
# 3050  3051.0      03/02/2020            NaN  ...    0.0       0.0     03/02
#
# [5 rows x 9 columns]

# %% [markdown]
# ## **Function to plot the graphs**
#
# Parameters:
#
#
# *   Graph -> seaborn plot;
# *   Title -> String which will be the graph's title

# %%
def plot_graph_confirmed_cases(graph, title):
  graph.set_ylabel('Confirmed Cases');
  graph.set_xlabel('Date');
  graph.grid(1);
  graph.set_title(title);

# %% [markdown]
# ## **Analyzing graph for each country**

# %%
plt.figure(figsize=(20,5));

plot_graph_confirmed_cases(
    sbn.lineplot(
      x='MonthDay', 
      y='Confirmed', 
      hue='Country/Region', 
      marker='o', data=covid_19_country1), 
    'Confirmed Cases in ' + country1);

plt.xticks(
    rotation=45, 
    horizontalalignment='right', 
);

# %%
plt.figure(figsize=(20,5));

plot_graph_confirmed_cases(
    sbn.lineplot(
      x='MonthDay', 
      y='Confirmed', 
      hue='Country/Region', 
      marker='o', data=covid_19_country2), 
    'Confirmed Cases in ' + country2);

plt.xticks(
    rotation=45, 
    horizontalalignment='right', 
);

# %%
plt.figure(figsize=(20,5));

plot_graph_confirmed_cases(
    sbn.lineplot(
      x='MonthDay', 
      y='Confirmed', 
      hue='Country/Region', 
      marker='o', data=covid_19_country3), 
    'Confirmed Cases in ' + country3);

plt.xticks(
    rotation=45, 
    horizontalalignment='right', 
);

# %% [markdown]
# # **Comparing Confirmed Cases on each country**

# %%
covid_19_compare = csv_covid_19[(csv_covid_19['Country/Region']==country1) | (csv_covid_19['Country/Region']==country2) | (csv_covid_19['Country/Region']==country3)]
covid_19_compare.sort_values(by='ObservationDate').head()
# Out:
#        SNo ObservationDate Province/State  ... Deaths Recovered  MonthDay
# 2564  2565      02/27/2020            NaN  ...    0.0       0.0     02/27
# 2674  2675      02/28/2020            NaN  ...    0.0       0.0     02/28
# 2677  2678      02/28/2020            NaN  ...    0.0       0.0     02/28
# 2790  2791      02/29/2020            NaN  ...    0.0       0.0     02/29
# 2794  2795      02/29/2020            NaN  ...    0.0       0.0     02/29
#
# [5 rows x 9 columns]

# %%
plt.figure(figsize=(20,5));

plot_graph_confirmed_cases(
    sbn.lineplot(
      x='MonthDay', 
      y='Confirmed', 
      hue='Country/Region', 
      marker='o', data=covid_19_compare), 
    'Comparision between ' + country1 + ', ' + country2 + " and " + country3);

plt.xticks(
    rotation=45, 
    horizontalalignment='right', 
);
